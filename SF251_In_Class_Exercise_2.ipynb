# %% [markdown]
# <a href="https://colab.research.google.com/github/PerawitDeawpanich/CN334-Template-Perawit/blob/master/SF251_In_Class_Exercise_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # In-Class Exercise 2
#
# Once done, upload to MS Teams

# %% [markdown]
# ## Pokemon Dataset Part 2
#
# Data from https://www.kaggle.com/datasets/cristobalmitchell/pokedex
#
# This time we will plot some graphs

# %%
# !wget https://raw.githubusercontent.com/yongsa-nut/SF251_67_2/refs/heads/main/data/pokemon.csv
# Out:
# --2026-02-24 13:29:18--  https://raw.githubusercontent.com/yongsa-nut/SF251_67_2/refs/heads/main/data/pokemon.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 331632 (324K) [text/plain]
# Saving to: ‘pokemon.csv.1’
#
# pokemon.csv.1       100%[===================>] 323.86K  --.-KB/s    in 0.03s
#
# 2026-02-24 13:29:18 (9.57 MB/s) - ‘pokemon.csv.1’ saved [331632/331632]

# %%
import pandas as pd
from plotnine import *

# %%
#Load the data
pokemon = pd.read_csv("pokemon.csv")
pokemon.head()
# Out:
#    national_number gen english_name japanese_name primary_type secondary_type  \
# 0                1   I    Bulbasaur   Fushigidane        grass         poison
# 1                2   I      Ivysaur    Fushigisou        grass         poison
# 2                3   I     Venusaur   Fushigibana        grass         poison
# 3                4   I   Charmander      Hitokage         fire            NaN
# 4                5   I   Charmeleon       Lizardo         fire            NaN
#
#    classification percent_male percent_female  height_m  ...  evochain_1  \
# 0    Seed Pokémon        88.14          11.86       0.7  ...      Level
# 1    Seed Pokémon        88.14          11.86       1.0  ...      Level
# 2    Seed Pokémon        88.14          11.86       2.0  ...      Level
# 3  Lizard Pokémon        88.14          11.86       0.6  ...      Level
# 4   Flame Pokémon        88.14          11.86       1.1  ...      Level
#
#    evochain_2  evochain_3  evochain_4  evochain_5  evochain_6  \
# 0     Ivysaur      Level     Venusaur         NaN         NaN
# 1     Ivysaur      Level     Venusaur         NaN         NaN
# 2     Ivysaur      Level     Venusaur         NaN         NaN
# 3  Charmeleon      Level    Charizard         NaN         NaN
# 4  Charmeleon      Level    Charizard         NaN         NaN
#
#             gigantamax  mega_evolution  mega_evolution_alt  \
# 0                  NaN             NaN                 NaN
# 1                  NaN             NaN                 NaN
# 2  Gigantamax Venusaur   Mega Venusaur                 NaN
# 3                  NaN             NaN                 NaN
# 4                  NaN             NaN                 NaN
#
#                                          description
# 0  There is a plant seed on its back right from t...
# 1  When the bulb on its back grows large, it appe...
# 2  Its plant blooms when it is absorbing solar en...
# 3  It has a preference for hot things. When it ra...
# 4  It has a barbaric nature. In battle, it whips ...
#
# [5 rows x 55 columns]

# %% [markdown]
# **Q1**: Plot the distribution of `attack` using histogram

# %%
ggplot(pokemon, aes(x='attack')) + \
    geom_histogram(binwidth=10, fill='skyblue', color='black') + \
    theme(figure_size=(8,5))

# %% [markdown]
# **Q2**: Plot a graph of `primary_type` using barplot. You can use `theme(figure_size=(x,y))` to make your graph bigger.

# %%
ggplot(pokemon, aes(x='primary_type')) + \
    geom_bar(fill='orange') + \
    theme(axis_text_x=element_text(rotation=45, hjust=1),
          figure_size=(10,5))

# %% [markdown]
# **Q3**: Plot a graph of `secondary_type` using barplot. What did you see?

# %%
ggplot(pokemon, aes(x='secondary_type')) + \
    geom_bar(fill='green') + \
    theme(axis_text_x=element_text(rotation=45, hjust=1),
          figure_size=(10,5))

# %% [markdown]
# **Q4**: Plot a graph for `secondary_type` again but this time only do not include `nan` in the plot. (Subset your data to exclude `nan` first using `notna()` or `isna()` with `~` e.g., `pokemon[pokemon[...].notna()]`)

# %%
#pokemon_filtered = pokemon[~ pokemon['secondary_type'].isna()] # pokemon[pokemon['secondary_type].notna()]
pokemon_filtered = pokemon[pokemon['secondary_type'].notna()]

ggplot(pokemon_filtered, aes(x='secondary_type')) + \
    geom_bar(fill='purple') + \
    theme(axis_text_x=element_text(rotation=45, hjust=1),
          figure_size=(10,5))

# %% [markdown]
# **Q5**: Plot a scatterplot between `attack` and `defense`

# %%
ggplot(pokemon, aes(x='attack', y='defense')) + \
    geom_point(color='red') + \
    theme(figure_size=(7,5))

# %% [markdown]
# **Q6**: Plot a scatterplot between `attack` and `defense` colored by `gen`

# %%
ggplot(pokemon, aes(x='attack', y='defense', color='factor(gen)')) + \
    geom_point() + \
    theme(figure_size=(7,5))

# %% [markdown]
# **Q7**: Plot a boxplot of `speed`

# %%
ggplot(pokemon, aes(y='speed')) + \
    geom_boxplot(fill='cyan') + \
    theme(figure_size=(5,6))

# %% [markdown]
# **Q8**: Add a violen plot to the previous plot.

# %%
ggplot(pokemon, aes(y='speed')) + \
    geom_violin(fill='lightgreen') + \
    geom_boxplot(width=0.1) + \
    theme(figure_size=(5,6))

# %% [markdown]
# **Q9**: Plot a boxplot of `speed` and `primary_type`. `primary_type` should be x axis.

# %%
ggplot(pokemon, aes(x='primary_type', y='speed')) + \
    geom_boxplot() + \
    theme(axis_text_x=element_text(rotation=45, hjust=1),
          figure_size=(12,6))

# %% [markdown]
# **Q10**: From the previous plot, which type has the highest median speed?

# %%
Electric type มี median speed สูงสุด
# Out:
#   File "/tmp/ipython-input-4107988085.py", line 1
#     Electric type มี median speed สูงสุด
#              ^
# SyntaxError: invalid syntax
